# %%
# 1. Mount Drive
from google.colab import drive, userdata
import os

drive.mount("/content/drive")

# 2. Define path and move into it
REPO_NAME = "learn_cv"
PROJECT_PATH = f"/content/drive/MyDrive/{REPO_NAME}"
# %cd {PROJECT_PATH}

# 3. Quick Git setup
# !git config --global user.email "petwen1027@gmail.com"
# !git config --global user.name "Peter Wen"
